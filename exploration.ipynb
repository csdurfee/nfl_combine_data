# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import get_combine_data

dataframes = get_combine_data.get_data()
combine_data = get_combine_data.process_data(dataframes)
# Out:
# /Users/caseydurfee/.virtualenvs/py3-data/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.0.0)/charset_normalizer (2.0.11) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
combine_data
# Out:
#                 Player  Pos                School    Ht     Wt  40yd  \
# 0         John Abraham  OLB        South Carolina   6-4  252.0  4.55
# 1      Shaun Alexander   RB               Alabama   6-0  218.0  4.58
# 2       Darnell Alford   OT           Boston Col.   6-4  334.0  5.56
# 3         Kyle Allamon   TE            Texas Tech   6-2  253.0  4.97
# 4     Rashard Anderson   CB         Jackson State   6-2  206.0  4.55
# ...                ...  ...                   ...   ...    ...   ...
# 3645     Jason Worilds  OLB         Virginia Tech   6-1  254.0  4.65
# 3646  Doug Worthington   DT            Ohio State   6-5  292.0  5.02
# 3647      Major Wright    S               Florida  5-11  206.0  4.44
# 3648         Sam Young   OT            Notre Dame   6-8  316.0  5.20
# 3649      Willie Young   DE  North Carolina State   6-5  251.0  4.88
#
#       Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0          NaN    NaN         NaN    NaN      NaN
# ...

# %%
olbs = combine_data[combine_data.Pos == "OLB"]
olbs.sort_values("DraftNumber")
olbs.corr()['DraftNumber']
# Out:
# Wt            -0.177678
# 40yd           0.390895
# Vertical      -0.320882
# Bench         -0.175506
# Broad Jump    -0.376523
# 3Cone          0.253547
# Shuttle        0.182196
# CombineYear    0.063993
# DraftNumber    1.000000
# Name: DraftNumber, dtype: float64

# %%
by_position = combine_data.pivot('Pos')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 by_position = combine_data.pivot('Pos')
#
# File ~/.virtualenvs/py3-data/lib/python3.9/site-packages/pandas/core/frame.py:6678, in DataFrame.pivot(self, index, columns, values)
#    6673 @Substitution("")
#    6674 @Appender(_shared_docs["pivot"])
#    6675 def pivot(self, index=None, columns=None, values=None) -> "DataFrame":
#    6676     from pandas.core.reshape.pivot import pivot
# -> 6678     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.virtualenvs/py3-data/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:445, in pivot(data, index, columns, values)
#     436 @Substitution("\ndata : DataFrame")
#     437 @Appender(_shared_docs["pivot"], indents=1)
#     438 def pivot(
#    (...)
#     442     values: Optional[Union[Label, Sequence[Label]]] = None,
# ...

# %%
sns.scatterplot(data=olbs, x='Broad Jump', y='DraftNumber')
# Out:
# <AxesSubplot:xlabel='Broad Jump', ylabel='DraftNumber'>
